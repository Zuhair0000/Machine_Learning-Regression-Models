# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuhair0000/Machine_Learning-Regression-Models/blob/main/updated_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer

# %% [markdown]
# ### Load Dataset

# %%
dataset = pd.read_csv("Data.csv")
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %% [markdown]
# ### Encode categorical features

# %%
categorical_transformer = Pipeline(steps=[
    ('encoder', OneHotEncoder())
])

# %% [markdown]
# ### Numeric feature

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %% [markdown]
# ### Apply preprocessing

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numerical_features),
    ('cat', categorical_transformer, categorical_features)
])

X_processed = preprocessor.fit_transform(X)

# %% [markdown]
# ### Model Training

# %%
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())
])

model_pipeline.fit(X_train, y_train)
y_pred = model_pipeline.predict(X_test)
